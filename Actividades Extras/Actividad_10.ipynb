# %% [markdown]
# # ESCUELA POLITECNICA NACIONAL
# # FACULTAD DE INGENIERIA EN SISTEMAS
# # METODOS NUMERICOS
#
# Nombre: Melanie Peñafiel Jácome

# %% [markdown]
# Fecha de entrega: 22 / 05 / 2026
#
# ----
#
# # Actividad Extra 10 - Confabulación en los modelos del lenguaje
#
# --------
#
# # Indicaciones:
#
# * Use el modelo de lenguaje de su preferencia (i.e. ChatGPT, Claude, Gemini, etc), determine la versión que utiliza y el modo de uso.
# * Escriba 3 prompts que den una respuesta incorrecta, describa dónde se encuentra el error.
# * Los prompts pueden ser de cualquier tipo (preguntas de cultura general, matemáticos, de razonamiento, etc) siempre y cuando solo haya una única respuesta coherente.
# * Realice capturas de pantalla para cada uno de los 3 ejemplos.
#
# -----
#
# # Modelo: Chat GPT - 5.1
#
# 1. Prompt:
#
# "Dime la lista completa de libros que escribió Gabriel García Márquez en 1978."

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# El modelo incluyó una recopilación periodística como si fuera un libro publicado, lo que demuestra una confusión entre tipos de obras y una interpretación incorrecta del contexto histórico.

# %% [markdown]
# 2. Prompt:
# "¿Cual es la derivada de $X2$?"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Es muy interesante este ejemplo de alucionación, los modelos de IA tienen un increible entrenamiento de datos, y es complicado que alguna caiga en una alucinación, pero no se salvan de preguntas matemáticas criticas como el ejemplo de esa derivada.

# %% [markdown]
# 3. Prompt:
# "Dame la serie de Tylor alrededor de x = 0"

# %% [markdown]
# ![image.png](attachment:image.png)
